# %%
import pandas as pd
import numpy as np
import random

# %%
raw_data=pd.DataFrame()
# raw_data['r1']=np.linspace(1,30,1000)
# raw_data['r2']=np.linspace(31,70,1000)
# raw_data['r3']=np.linspace(71,130,1000)
# raw_data['r4']=np.linspace(131,230,1000)
# raw_data['r5']=np.linspace(231,290,1000)
# raw_data['r6']=np.linspace(291,360,1000)

raw_data['r1']=np.random.uniform(0, 30, 1000)
raw_data['r2']=np.random.uniform(31, 70, 1000)
raw_data['r3']=np.random.uniform(71, 130, 1000)
raw_data['r4']=np.random.uniform(131, 230, 1000)
raw_data['r5']=np.random.uniform(231,290,1000)
raw_data['r6']=np.random.uniform(291,360,1000)
print(raw_data)
# Out:
#             r1         r2          r3          r4          r5          r6
# 0     3.054430  65.231574   84.607661  217.488100  254.685420  324.590589
# 1    19.775631  45.459703   76.929219  147.604362  243.632019  311.722126
# 2    12.377811  65.076842  117.746162  131.757568  263.325380  345.714087
# 3    25.981592  68.048753   97.774060  187.160191  278.031320  358.650888
# 4    26.685339  56.891270   86.148610  167.594608  234.814228  321.304699
# ..         ...        ...         ...         ...         ...         ...
# 995   8.640642  62.999186   75.678777  196.187690  238.466154  355.040186
# 996  21.366921  35.253751  100.607237  178.424160  250.653003  318.754864
# 997  16.897009  65.004138   95.676063  191.746504  263.782712  296.279205
# 998  19.540699  49.008643   94.991485  178.019325  243.840233  321.805305
# 999  27.282692  39.131604   95.786344  210.404773  288.528222  344.124512
#
# [1000 rows x 6 columns]

# %%
# categories=['Unripe','Early Ripe','Over Ripe','Partially Ripe']
temp23=np.random.choice([1,2,3,4], 1000)

# categories=['Unripe','Early Ripe','Over Ripe','Partially Ripe']
# classes=[]

# for _ in range(len(raw_data)):
#   temp=np.random.choice(categories,1)
#   classes.append(temp[0])
# raw_data['Class']=classes
temp23
raw_data['Class']=temp23.astype(float)

# %%
raw_data.head()
# Out:
#           r1         r2          r3          r4          r5          r6  Class
# 0   3.054430  65.231574   84.607661  217.488100  254.685420  324.590589    4.0
# 1  19.775631  45.459703   76.929219  147.604362  243.632019  311.722126    4.0
# 2  12.377811  65.076842  117.746162  131.757568  263.325380  345.714087    1.0
# 3  25.981592  68.048753   97.774060  187.160191  278.031320  358.650888    2.0
# 4  26.685339  56.891270   86.148610  167.594608  234.814228  321.304699    3.0

# %%
from sklearn.preprocessing import StandardScaler
X_columns=['r1', 'r2', 'r3', 'r4', 'r5', 'r6']
X=raw_data[X_columns]
scaler = StandardScaler()
scaler.fit(X)
scaled_features = scaler.transform(X)
scaled_features
# Out:
# array([[-1.4357865 ,  1.31388908, -0.89481301,  1.28121646, -0.30858537,
#         -0.05468352],
#        [ 0.54366607, -0.43334418, -1.35625727, -1.16419506, -0.96433913,
#         -0.69550781],
#        [-0.33208649,  1.30021552,  1.09668093, -1.71871506,  0.20398864,
#          0.9972253 ],
#        ...,
#        [ 0.20289525,  1.29379071, -0.22964548,  0.38045188,  0.23112031,
#         -1.46453498],
#        [ 0.51585476, -0.11972559, -0.27078591, -0.09989737, -0.95198667,
#         -0.19338525],
#        [ 1.43235044, -0.99255606, -0.22301802,  1.03335263,  1.6991717 ,
#          0.91806758]])

# %%
df_feat = pd.DataFrame(scaled_features,columns=X_columns)
df_feat.head()
# Out:
#          r1        r2        r3        r4        r5        r6
# 0 -1.435786  1.313889 -0.894813  1.281216 -0.308585 -0.054684
# 1  0.543666 -0.433344 -1.356257 -1.164195 -0.964339 -0.695508
# 2 -0.332086  1.300216  1.096681 -1.718715  0.203989  0.997225
# 3  1.278326  1.562842 -0.103564  0.219965  1.076433  1.641453
# 4  1.361636  0.576859 -0.802208 -0.464685 -1.487463 -0.218314

# %%
raw_data.dtypes
# Out:
# r1       float64
# r2       float64
# r3       float64
# r4       float64
# r5       float64
# r6       float64
# Class    float64
# dtype: object

# %%
raw_data.head()
# Out:
#           r1         r2          r3          r4          r5          r6  Class
# 0   3.054430  65.231574   84.607661  217.488100  254.685420  324.590589    4.0
# 1  19.775631  45.459703   76.929219  147.604362  243.632019  311.722126    4.0
# 2  12.377811  65.076842  117.746162  131.757568  263.325380  345.714087    1.0
# 3  25.981592  68.048753   97.774060  187.160191  278.031320  358.650888    2.0
# 4  26.685339  56.891270   86.148610  167.594608  234.814228  321.304699    3.0

# %%
raw_data.tail()
# Out:
#             r1         r2          r3          r4          r5          r6  \
# 995   8.640642  62.999186   75.678777  196.187690  238.466154  355.040186
# 996  21.366921  35.253751  100.607237  178.424160  250.653003  318.754864
# 997  16.897009  65.004138   95.676063  191.746504  263.782712  296.279205
# 998  19.540699  49.008643   94.991485  178.019325  243.840233  321.805305
# 999  27.282692  39.131604   95.786344  210.404773  288.528222  344.124512
#
#      Class
# 995    2.0
# 996    1.0
# 997    4.0
# 998    4.0
# 999    1.0

# %%
raw_data['Class'].value_counts()
# Out:
# 4.0    268
# 1.0    259
# 2.0    244
# 3.0    229
# Name: Class, dtype: int64

# %%
# raw_data['Class'] = pd.to_numeric(raw_data['Class'],errors='coerce').notnull()
# raw_data['Class'] = raw_data['Class'].astype('float')
# raw_data.dtypes

# %%
raw_data['Class'].value_counts()
# Out:
# 4.0    268
# 1.0    259
# 2.0    244
# 3.0    229
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt

Early_Ripe_df=raw_data[raw_data['Class']==1.0][0:200]
Unripe_df=raw_data[raw_data['Class']==2.0][0:200]
Partially_Ripe_df=raw_data[raw_data['Class']==3.0][0:200]
Over_Ripe_df=raw_data[raw_data['Class']==4.0][0:200]

# axes1 = Early_Ripe_df.plot(kind='scatter',x='r1',y='r2',color='red',label='Early_Ripe')
# axes2 = Unripe_df.plot(kind='scatter',x='r1',y='r2',color='blue',label='Unripe')
# axes3 = Partially_Ripe_df.plot(kind='scatter',x='r1',y='r2',color='green',label='Partially_Ripe')
# Over_Ripe_df.plot(kind='scatter',x='r1',y='r2',color='yellow',label='Over_Ripe', ax= (axes1,axes2,axes3))

fig, ax = plt.subplots()

# Scatter plots for each class
Early_Ripe_df.plot(kind='scatter', x='r1', y='r2', color='red', label='Early_Ripe', ax=ax)
Unripe_df.plot(kind='scatter', x='r1', y='r2', color='blue', label='Unripe', ax=ax)
Partially_Ripe_df.plot(kind='scatter', x='r1', y='r2', color='green', label='Partially_Ripe', ax=ax)
Over_Ripe_df.plot(kind='scatter', x='r1', y='r2', color='yellow', label='Over_Ripe', ax=ax)

# Show the legend
ax.legend()

# Show the plot
plt.show()

# %%
raw_data.dtypes
# Out:
# r1       float64
# r2       float64
# r3       float64
# r4       float64
# r5       float64
# r6       float64
# Class    float64
# dtype: object

# %%
raw_data.columns
# Out:
# Index(['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'Class'], dtype='object')

# %%
feature_df= raw_data[['r1', 'r2', 'r3', 'r4', 'r5', 'r6']]
feature_df.head()
# Out:
#           r1         r2          r3          r4          r5          r6
# 0   3.054430  65.231574   84.607661  217.488100  254.685420  324.590589
# 1  19.775631  45.459703   76.929219  147.604362  243.632019  311.722126
# 2  12.377811  65.076842  117.746162  131.757568  263.325380  345.714087
# 3  25.981592  68.048753   97.774060  187.160191  278.031320  358.650888
# 4  26.685339  56.891270   86.148610  167.594608  234.814228  321.304699

# %%
X= np.asarray(feature_df)
X.size
# Out:
# 6000

# %%
y=np.asarray(raw_data['Class'])
y.size
# Out:
# 1000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.45,random_state=25)
X_train.shape
# Out:
# (550, 6)

# %%
y_train.shape
# Out:
# (550,)

# %%
X_test.shape
# Out:
# (450, 6)

# %%
y_test.shape
# Out:
# (450,)

# %%
X_train.shape
# Out:
# (550, 6)

# %%
from sklearn import svm

#SVC - support vector classifier - those data points near to the hyperplace and are pendicular .If we sum the sum nearby points of hyperplane and maximise the distance . those



# Types of SVC
# Linear
# polynomial
# radial basis function
# Sigmoid

# Gamma - kernel coefficients
# C - penaltity for incorrect data points

Classifier= svm.SVC(kernel='linear', gamma='auto', C=2)

# %%
Classifier.fit(X_train,y_train)
y_predict= Classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.34      0.32      0.33       125
#          2.0       0.22      0.41      0.28        98
#          3.0       0.15      0.05      0.07       106
#          4.0       0.23      0.22      0.23       121
#
#     accuracy                           0.25       450
#    macro avg       0.24      0.25      0.23       450
# weighted avg       0.24      0.25      0.23       450
#
# [[40 43 13 29]
#  [19 40  5 34]
#  [28 47  5 26]
#  [29 55 10 27]]
